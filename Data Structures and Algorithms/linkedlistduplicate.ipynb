# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None 
class Solution: 
    def insert(self,head,data):
            p = Node(data)           
            if head==None:
                head=p
            elif head.next==None:
                head.next=p
            else:
                start=head
                while(start.next!=None):
                    start=start.next
                start.next=p
            return head  
    def display(self,head):
        current = head
        while current:
            print(current.data,end=' ')
            current = current.next

    #*Test case failing for a lot of duplicates
    def removeDuplicates(self,head):
        '''
        #Write your code here
        #We are going to store all nodes in a set for fast lookup time. 

        #!Looking using current.next is a problem because the first element will not be added to the set. 
        #*I should figure out how to do it with while current
        
        allNodes = set()
        current = head
        prev = None
        #Checking by current.next is problem because doesn't check the last element.
        while current:
            #I also have to check whether current.next.next exists cuz that might be causing errors. 
            if current.data in allNodes:
                #Check for end

                #I do not need to check for beginning because there is nothing in the set at the beginning.
                #! I cannot let current.next point to None because then current=None the next time, and will stop looping.
                #*I can still let it point to current.next. But since element before will also point to current.next, it will be passed. 
                prev.next = current.next 
            else:
                allNodes.add(current.data)
            prev = current
            current = current.next

            #!The idea of prev is messing up the cases for multiple duplicates. 

        
        return head
        '''
            
        #!Honestly, I don't need to do everything at one step. 
        #*Though it will sacrifice some time, I can do it in 2 steps.
        allNodes = set()
        duplicateList = []
        #True when list should be there. False when it is a duplicate
        current = head
        prev = None
        while current:
            if current.data in allNodes:
                duplicateList.append(False)
            else:
                duplicateList.append(True)
                allNodes.add(current.data)
            current = current.next

        current = head
        prev = None
        counter = 0
        while current:
            if duplicateList[counter] == False:
                #Don't need to check for first element.
                #!We need to run a while loop because the next elements could also be duplicates.
                #We need to start checking the next one. 
                
                while duplicateList[counter] == False:
                    #!We have to check whether we have exceeded the length. 
                    #*This is to prevent index error. 
                    if counter < len(duplicateList)-1:
                        current = current.next
                        counter += 1

                    else:
                        #*I have to assign the last proper value's next value to none.
                        #*Just so the statement after the while loop passes, I will just increment current.
                        #*The whole issue is in incrementing counter. Incrementing current is fine. 
                        current = current.next
                        break
                prev.next = current

            #!When the current item isn't False
            else:
                counter += 1
                prev = current
                current = current.next

        return head
                


                






mylist= Solution()
T=int(input())
head=None
for i in range(T):
    data=int(input())
    head=mylist.insert(head,data)    
head=mylist.removeDuplicates(head)
mylist.display(head)

# %%
#The above solution worked but there is a better less code-intensive way to solve it as well. 
#An original approach I came up with is to store all the data values in a list first and remake the whole linked list. I mean it should work. 
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None 
class Solution: 
    def insert(self,head,data):
            p = Node(data)           
            if head==None:
                head=p
            elif head.next==None:
                head.next=p
            else:
                start=head
                while(start.next!=None):
                    start=start.next
                start.next=p
            return head  
    def display(self,head):
        current = head
        while current:
            print(current.data,end=' ')
            current = current.next


    def removeDuplicates(self,head):
        dataValues = []
        current = head
        new_head = None
        while current:
            if current.data not in dataValues:
                dataValues.append(current.data)
            current = current.next

        #Swap them all into a node
        for i in range(0, len(dataValues)):
            dataValues[i] = Node(dataValues[i])

        for in range(0, len(dataValues)-1):
            dataValues[i].next = dataValues[i+1]

        head = dataValues[0]
        return head

        

        
            

mylist= Solution()
T=int(input())
head=None
for i in range(T):
    data=int(input())
    head=mylist.insert(head,data)    
head=mylist.removeDuplicates(head)
mylist.display(head);

# %%
#2. A recursive function based on a comment
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None 
class Solution: 
    def insert(self,head,data):
            p = Node(data)           
            if head==None:
                head=p
            elif head.next==None:
                head.next=p
            else:
                start=head
                while(start.next!=None):
                    start=start.next
                start.next=p
            return head  
    def display(self,head):
        current = head
        while current:
            print(current.data,end=' ')
            current = current.next


    def removeDuplicates(self,head):
        #This both covers the case when there are no elements and there is one element. This also covers the last element.
        if head == None or head.next == None:
            return head

        #At first, this may seem as if it is only checking the 
        if head.data == head.next.data:
            head.next = head.next.next
            removeDuplicates(head)

        else:
            removeDuplicates(head.next)

        return head


        

        
            

mylist= Solution()
T=int(input())
head=None
for i in range(T):
    data=int(input())
    head=mylist.insert(head,data)    
head=mylist.removeDuplicates(head)
mylist.display(head);
