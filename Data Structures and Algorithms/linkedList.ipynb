# %%
#This is essentially an element of a linked list. 
class Element(object):
    def __init__(self, value):
        self.value = value
        self.next = None

#In this class, the head element is the first element in the linked list. The self.head = new_element reference is for when the Linked list is empty and I am appending the first element. 
class LinkedList(object):
    def __init__(self, head=None):
        self.head = head

    def append(self, new_element):
        #Points to the header
        current = self.head
        if self.head:
            while current.next:
                current = current.next
            current.next = new_element
        else:
            self.head = new_element
            

    def get_position(self, position):
        """Get an element from a particular position.
        Assume the first position is "1".
        Return "None" if position is not in the list."""

        firstPos = 1
        current = self.head
        if self.head:
            while current:
                if firstPos == position:
                    return current
                #But this doesn't pass the change the next value to the next value though
                current = current.next
                firstPos += 1

        return None
    
    def insert(self, new_element, position):
        """Insert a new node at the given position.
        Assume the first position is "1".
        Inserting at position 3 means between
        the 2nd and 3rd elements."""
        firstPos = 2
        current = self.head
        added_element = None

        if self.head:
            while current:
                
                if firstPos == position:
                    #Create the element. I don't need to do this because new_element is already an Element                       object
                    #the next value for the added element. 
                    new_element.next = current.next
                    #Change value of value before the new element
                    current.next = new_element
                    break
                
                current = current.next
                firstPos += 1


    def delete(self, value):
        """Delete the first node with a given value."""
        firstPos = 1
        current = self.head 
        previous = None
        #Just for the delete method, things have to revolve based on the next value because I have to make           modifications to the previous value. But that still won't solve the problem for the first item. I            I will have to make a temporary value that stores the previous value. 
        if self.head:
            while current:
                #Doesn't this have to include the head too though?
                if value == current.value:
                    #Could make possibilities for the first element.
                    if previous:
                        previous.next = current.next
                    else:
                        self.head = current.next
                    break
                #Maybe problems with mutation
                previous = current
                current = current.next

    def showList(self):
        outputList = []
        current = self.head
        if self.head:
            while current:
                if current.next:
                    outputList.append([f"current: {current.value}, next: {current.next.value}"])
                else:
                    outputList.append([f"current: {current.value}, next: {None}"])
                current = current.next
            
        return outputList
                
# Test cases
# Set up some Elements
e1 = Element(1)
e2 = Element(2)
e3 = Element(3)
e4 = Element(4)

# Start setting up a LinkedList
ll = LinkedList(e1)
ll.append(e2)
ll.append(e3)

# Test get_position
# Should print 3
print(ll.head.next.next.value)
# Should also print 3
print(ll.get_position(3).value)

print(ll.showList())

# Test insert
ll.insert(e4,3)
# Should print 4 now
print(ll.get_position(3).value)

print(ll.showList())

# Test delete
ll.delete(1)
# Should print 2 now
print(ll.get_position(1).value)
# Should print 4 now
print(ll.get_position(2).value)
# Should print 3 now
print(ll.get_position(3).value)

print(ll.showList())
'''Correct Test Cases
3
3
4
2
4
3
'''
# Out:
# 3
# 3
# [['current: 1, next: 2'], ['current: 2, next: 3'], ['current: 3, next: None']]
# 4
# [['current: 1, next: 2'], ['current: 2, next: 4'], ['current: 4, next: 3'], ['current: 3, next: None']]
# 2
# 4
# 3
# [['current: 2, next: 4'], ['current: 4, next: 3'], ['current: 3, next: None']]
# 'Correct Test Cases\n3\n3\n4\n2\n4\n3\n'

# %%
#Official solution. Accomodates more edge cases. 
class Element(object):
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList(object):
    def __init__(self, head=None):
        self.head = head

    def append(self, new_element):
        current = self.head
        if self.head:
            while current.next:
                current = current.next
            current.next = new_element
        else:
            self.head = new_element

    def get_position(self, position):
        counter = 1
        current = self.head
        if position < 1:
            return None
        while current and counter <= position:
            if counter == position:
                return current
            current = current.next
            counter += 1
        return None

    def insert(self, new_element, position):
        #First element in the linked list is treated as if it is at index 1. 
        counter = 1
        current = self.head
        if position > 1:
            while current and counter < position:
                if counter == position - 1:
                    new_element.next = current.next
                    current.next = new_element
                current = current.next
                counter += 1
        elif position == 1:
            new_element.next = self.head
            self.head = new_element

    def delete(self, value):
        current = self.head
        previous = None
        while current.value != value and current.next:
            previous = current
            current = current.next
        if current.value == value:
            if previous:
                previous.next = current.next
            else:
                self.head = current.next

    def showList(self):
        outputList = []
        current = self.head
        if self.head:
            while current:
                if current.next:
                    outputList.append([f"current: {current.value}, next: {current.next.value}"])
                else:
                    outputList.append([f"current: {current.value}, next: {None}"])
                current = current.next
            
        return outputList


e1 = Element(1)
e2 = Element(2)
e3 = Element(3)
e4 = Element(4)


ll = LinkedList(e1)
ll.append(e2)
ll.append(e3)

print(ll.showList())
ll.insert(e4, 2)
print(ll.showList())
# Out:
# [['current: 1, next: 2'], ['current: 2, next: 3'], ['current: 3, next: None']]
# [['current: 1, next: 2'], ['current: 2, next: 4'], ['current: 4, next: 3'], ['current: 3, next: None']]
