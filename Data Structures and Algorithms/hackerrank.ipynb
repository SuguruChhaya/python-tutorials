# %%
#https://www.hackerrank.com/challenges/insert-a-node-at-a-specific-position-in-a-linked-list/problem?h_l=interview&playlist_slugs%5B%5D=interview-preparation-kit&playlist_slugs%5B%5D=linked-lists

#A node is an intersection or connection within a network.

# %%
#https://www.hackerrank.com/challenges/reverse-a-doubly-linked-list/problem?h_l=interview&playlist_slugs%5B%5D=interview-preparation-kit&playlist_slugs%5B%5D=linked-lists

#Reversing a linked list isn't that hard after all. Just have to loop through all the things. 
#The answer choice wrote it in a pretty simple way but there is quite a bit behind it.

# %%
#Code to reverse a singly linked list iteratively. 
class Node: 
  
    # Constructor to initialize the node object 
    def __init__(self, data): 
        self.data = data 
        self.next = None
  
class LinkedList: 
  
    # Function to initialize head 
    def __init__(self): 
        self.head = None
  
    # Function to reverse the linked list 
    def reverse(self): 
        prev = None
        current = self.head 
        while(current is not None): 
            #Just for storing purposes. 
            next = current.next
            #Switching direction
            current.next = prev 
            #Moving the "prev" pointer by one
            prev = current 
            #Moving the "current" pointer by one. 
            current = next


        self.head = prev 
          
    # Function to insert a new node at the beginning 
    def push(self, new_data): 
        new_node = Node(new_data) 
        new_node.next = self.head 
        self.head = new_node 
  
    # Utility function to print the linked LinkedList 
    def printList(self): 
        temp = self.head 
        while(temp): 
            print(temp.data) 
            temp = temp.next
  
  
# Driver program to test above functions 
llist = LinkedList() 
llist.push(20) 
llist.push(4) 
llist.push(15) 
llist.push(85) 
  
print("Given Linked List")
llist.printList() 
llist.reverse() 
print("\nReversed Linked List")
llist.printList()
# Out:
# Given Linked List
# 85
# 15
# 4
# 20
#
# Reversed Linked List
# 20
# 4
# 15
# 85

# %%
#Code to reverse a singly linked list recursively. 
class Node: 
  
    # Constructor to initialize the node object 
    def __init__(self, data): 
        self.data = data 
        self.next = None
  
class LinkedList: 
  
    # Function to initialize head 
    def __init__(self): 
        self.head = None
  
    # Function to reverse the linked list 
    def reverseList(self, node):
        #In order to reverse recursively, self.head must be stored must be be alterable everytime I run the function. Hackerrank doesn't offer me that environment. 
        if node.next == None:
            self.head = node
            return
        
        self.reverseList(node=node.next)
        next_node = node.next 
        next_node.next = node
        node.next = None


        
          
    # Function to insert a new node at the beginning 
    def push(self, new_data): 
        new_node = Node(new_data) 
        new_node.next = self.head 
        self.head = new_node 
  
    # Utility function to print the linked LinkedList 
    def printList(self): 
        temp = self.head 
        while(temp): 
            print(temp.data) 
            temp = temp.next
  
  
# Driver program to test above functions 
llist = LinkedList() 
llist.push(20) 
llist.push(4) 
llist.push(15) 
llist.push(85) 
  
print("Given Linked List")
llist.printList() 
llist.reverseList(llist.head)
print("\nReversed Linked List")
llist.printList()
# Out:
# Given Linked List
# 85
# 15
# 4
# 20
#
# Reversed Linked List
# 20
# 4
# 15
# 85

# %%
#What I have so far for the linked list merge point question:
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the findMergeNode function below.
#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def findMergeNode(head1, head2):
    #Super bad time complexity but gotta try. 
    #I can just compare the length of the 2 linked lists and whichever is larger I can just go get the data value for that one. 
    head1_counter = 0
    head2_counter = 0
    
    #We should get the total length for when it merged at a specific value. 
    head1_current = head1
    head2_current = head2
    while head1_current:
        head2_current = head2
        while head2_current:
            if head1_current.data == head2_current.data:
                return head1_current.data
            head2_current = head2_current.next
        head1_current = head1_current.next
        
    #I don't understand why head2_current is larger than I expected in head2_current
    while head2_current:
        head2_counter += 1
        head2_current = head2_current.next
            
    print(head1_counter)
    print(head2_counter)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    tests = int(input())

    for tests_itr in range(tests):
        index = int(input())

        llist1_count = int(input())

        llist1 = SinglyLinkedList()

        for _ in range(llist1_count):
            llist1_item = int(input())
            llist1.insert_node(llist1_item)
            
        llist2_count = int(input())

        llist2 = SinglyLinkedList()

        for _ in range(llist2_count):
            llist2_item = int(input())
            llist2.insert_node(llist2_item)
            
        ptr1 = llist1.head;
        ptr2 = llist2.head;

        for i in range(llist1_count):
            if i < index:
                ptr1 = ptr1.next
                
        for i in range(llist2_count):
            if i != llist2_count-1:
                ptr2 = ptr2.next

        ptr2.next = ptr1

        result = findMergeNode(llist1.head, llist2.head)

        fptr.write(str(result) + '\n')

    fptr.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f57b67593f8d> in <module>
#      73
#      74 if __name__ == '__main__':
# ---> 75     fptr = open(os.environ['OUTPUT_PATH'], 'w')
#      76
#      77     tests = int(input())
#
# ~\AppData\Local\Programs\Python\Python39\lib\os.py in __getitem__(self, key)
#     677         except KeyError:
#     678             # raise KeyError with the original key value
# --> 679             raise KeyError(key) from None
#     680         return self.decodevalue(value)
#     681
#
# KeyError: 'OUTPUT_PATH'

# %%
#Code to reverse a singly linked list iteratively. 
class Node: 
  
    # Constructor to initialize the node object 
    def __init__(self, data): 
        self.data = data 
        self.next = None
  
class LinkedList: 
  
    # Function to initialize head 
    def __init__(self): 
        self.head = None
  
    # Function to reverse the linked list 
    def reverse(self):
        prev = None
        current = self.head
        while current:
            next = current.next
            current.next = prev
            prev = current
            current = next



        self.head = prev 
          
    # Function to insert a new node at the beginning 
    def push(self, new_data): 
        new_node = Node(new_data) 
        new_node.next = self.head 
        self.head = new_node 
  
    # Utility function to print the linked LinkedList 
    def printList(self): 
        temp = self.head 
        while(temp): 
            print(temp.data) 
            temp = temp.next
  
  
# Driver program to test above functions 
llist = LinkedList() 
llist.push(20) 
llist.push(4) 
llist.push(15) 
llist.push(85) 
  
print("Given Linked List")
llist.printList() 
llist.reverse() 
print("\nReversed Linked List")
llist.printList()
# Out:
# Given Linked List
# 85
# 15
# 4
# 20
#
# Reversed Linked List
# 20
# 4
# 15
# 85

# %%
#Code to reverse a singly linked list recursively. 
class Node: 
  
    # Constructor to initialize the node object 
    def __init__(self, data): 
        self.data = data 
        self.next = None
  
class LinkedList: 
  
    # Function to initialize head 
    def __init__(self): 
        self.head = None
  
    #Passing a node every time. Because we do this with every node.  
    def reverseList(self, node):
        if node.next == None:
            self.head = node 
            return 

        self.reverseList(node.next)
        node.next.next = node 
        node.next = None



        
          
    # Function to insert a new node at the beginning 
    def push(self, new_data): 
        new_node = Node(new_data) 
        new_node.next = self.head 
        self.head = new_node 
  
    # Utility function to print the linked LinkedList 
    def printList(self): 
        temp = self.head 
        while(temp): 
            print(temp.data) 
            temp = temp.next
  
  
# Driver program to test above functions 
llist = LinkedList() 
llist.push(20) 
llist.push(4) 
llist.push(15) 
llist.push(85) 
  
print("Given Linked List")
llist.printList() 
llist.reverseList(llist.head)
print("\nReversed Linked List")
llist.printList()
# Out:
# Given Linked List
# 85
# 15
# 4
# 20
#
# Reversed Linked List
# 20
# 4
# 15
# 85

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the findMergeNode function below.
#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#
def findListlen(head):
    len = 0
    current = head
    while current:
        len += 1
        current = current.next
        
    return len
        

def findMergeNode(head1, head2):
    #Super bad time complexity but gotta try. 
    #I can just compare the length of the 2 linked lists and whichever is larger I can just go get the data value for that one. 
    
    #Somehow only passes certain ones. 
    
    len_head1 = findListlen(head1)
    len_head2 = findListlen(head2)
    
    head1_current = head1
    head2_current = head2
    
    if len_head1 > len_head2:
        head1, head2 = head2, head1
        
    difference = len_head2 - len_head1
    
    for i in range(difference):
        head1_current = head1_current.next
        
    while head1_current != None and head2_current != None:
        if head1_current == head2_current:
            return head1_current.data
        head1_current = head1_current.next
        head2_current = head2_current.next
        
    #Just in case there are no merges
    
    
    '''
    addresses = set()
    head1_current = head1
    head2_current = head2
    while head2_current:
        addresses.add(head2_current)
        head2_current = head2_current.next
        
    while head1_current:
        if head1_current in addresses:
            return head1_current.data
        head1_current = head1_current.next
    
    head1_current = head1
    head2_current = head2
    '''
    '''
    for i in range(head1_len):
        head2_current = head2
        for j in range(head2_len):
            if head1_current == head2_current:
                return head1_current.data
                
            head2_current = head2_current.next
                
        head1_current = head1_current.next
    '''
        
                
        

if __name__ == '__main__':
