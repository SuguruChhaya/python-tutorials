# %%
#Binary search tree algorithm
class Node(object):
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinaryTree(object):
    def __init__(self, root):
        self.root = Node(root)

    def search(self, find_val):
        """Return True if the value
        is in the tree, return
        False otherwise."""
        return self.preorder_search(self.root, find_val)
        

    def print_tree(self):
        """Print out all tree nodes
        as they are visited in
        a pre-order traversal."""
        arr = []
        #Since arrays are mutable by passing through methods. 
        finalString =""
        self.preorder_print(self.root, arr)
        for item in arr:
            finalString += str(item) + "-"

        return finalString[:len(finalString)-1]




    def preorder_search(self, start, find_val):
        """Helper method - use this to create a 
        recursive search solution."""
        #Base case: start just has value None
        if start==None:
            return False
        elif start.value == find_val:
            return True
        elif start.value < find_val:
            return self.preorder_search(start.left, find_val)
        elif start.value > find_val:
            return self.preorder_search(start.right, find_val)
        
        return False

    def preorder_print(self, start, traversal):
        """Helper method - use this to create a 
        recursive print solution."""
        #Base case: when there are neither 
        if start== None:
            pass
        else:
            traversal.append(start.value)
            self.preorder_print(start.left, traversal)
            self.preorder_print(start.right, traversal)




# Set up tree
tree = BinaryTree(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)

# Test search
# Should be True
print(tree.search(4))
# Should be False
print(tree.search(6))

# Test print_tree
# Should be 1-2-4-5-3
print(tree.print_tree())

# %%
class Node(object):
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BST(object):
    def __init__(self, root):
        self.root = Node(root)

    def insert(self, new_val):
        prev, next = self.insertMain(self.root, None, new_val)
        new = Node(new_val)
        #Even though I can return as prev.left or prev.right from self.insertMain, I have to ultimately check here as well. I need to check whether next == None or not. 
        if next != None:
            if prev.value < next.value:
                prev.left, new.left = new, next
            else:
                prev.right, new
        else:
            if new_val < prev.value:
                prev.left = new
            else:
                prev.right = new
        


    def search(self, find_val):
        #We will search recursively. Since it does not allow to add current parameter, I will use as wrapper.
        
        return self.searchMain(find_val, self.root)

    def searchMain(self, find_val, current):
        if current == None:
            return False
        elif current.value == find_val:
            return True
        elif current.value < find_val:
            return self.searchMain(find_val, current.left)
        elif current.value > find_val:
            return self.searchMain(find_val, current.right)

    def insertMain(self, current, prev, new_val):
        #When prev is smaller and current is larger, we found the correct node. 
        #One possible exception when the node as to be added at the end. 
        #Return will be a tuple: (prev, current)

        #First need to check if prev exists
        if prev == None:
            if new_val < current.value:
                return self.insertMain(current.left, current, new_val)
            elif new_val > current.value:
                return self.insertMain(current.right, current, new_val)


        if current == None:
            #current just has to be None
            #But before, I just need to check
            if new_val < prev.value:
                return (prev, prev.left)
            else:
                return (prev, prev.right)
            #Not possible based on question
            '''
            elif current.value == find_val:
                return True
            '''
        elif prev.value < new_val < current.value:
            #I think I can check the next one right away. 
            return (prev, prev.right)
        elif prev.value > new_val > current.value:
            return (prev, prev.left)
        #Both current and prev are smaller. 
        elif prev.value < new_val:
            return self.insertMain(current.left, current, new_val)
        #Both current and prev are larger. 
        elif prev.value > new_val:
            return self.insertMain(current.right, current, new_val)
    def print_tree(self):
        """Print out all tree nodes
        as they are visited in
        a pre-order traversal."""
        arr = []
        #Since arrays are mutable by passing through methods. 
        finalString =""
        self.preorder_print(self.root, arr)
        for item in arr:
            finalString += str(item) + "-"

        return finalString[:len(finalString)-1]




    def preorder_search(self, start, find_val):
        """Helper method - use this to create a 
        recursive search solution."""
        #Base case: start just has value None
        if start==None:
            return False
        elif start.value == find_val:
            return True
        elif start.value < find_val:
            return self.preorder_search(start.left, find_val)
        elif start.value > find_val:
            return self.preorder_search(start.right, find_val)
        
        return False

    def preorder_print(self, start, traversal):
        """Helper method - use this to create a 
        recursive print solution."""
        #Base case: when there are neither 
        if start== None:
            pass
        else:
            traversal.append(start.value)
            self.preorder_print(start.left, traversal)
            self.preorder_print(start.right, traversal)
# Set up tree
tree = BST(4)

# Insert elements
tree.insert(2)
tree.insert(1)
tree.insert(3)
tree.insert(5)
print(tree.print_tree())

# Check search
# Should be True
print(tree.search(4))
# Should be False
print(tree.search(6))
# Out:
# 4-2-1-5
# True
# False

# %%
#Answer from udacity of inserting and checking
class Node(object):
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


class BST(object):
    def __init__(self, root):
        self.root = Node(root)

    def search(self, find_val):
        #We will search recursively. Since it does not allow to add current parameter, I will use as wrapper.
        
        return self.searchMain(find_val, self.root)

    def searchMain(self, find_val, current):
        if current == None:
            return False
        elif current.value == find_val:
            return True
        elif current.value < find_val:
            return self.searchMain(find_val, current.left)
        elif current.value > find_val:
            return self.searchMain(find_val, current.right)

    #Seems like I overthought the inserting method. I don't even need to keep track of prev. 
    def insert(self, new_val):
        #Firstly, I don't have to really return anything. 
        self.insert_helper(self.root, new_val)

    def insert_helper(self, current, new_val):
        #The solution doesn't really seem to take into consideration of some things. 
        if current.value < new_val:
            #If something on the right exists
            if current.right:
                self.insert_helper(current.right, new_val)
            else:
                #Though this will work at the highest level, what if I have to insert at middle levels?
                current.right = Node(new_val)
        else:
            if current.left:
                self.insert_helper(current.left, new_val)
            else:
                current.left = Node(new_val)

    def print_tree(self):
        """Print out all tree nodes
        as they are visited in
        a pre-order traversal."""
        arr = []
        #Since arrays are mutable by passing through methods. 
        finalString =""
        self.preorder_print(self.root, arr)
        for item in arr:
            finalString += str(item) + "-"

        return finalString[:len(finalString)-1]




    def preorder_search(self, start, find_val):
        """Helper method - use this to create a 
        recursive search solution."""
        #Base case: start just has value None
        if start==None:
            return False
        elif start.value == find_val:
            return True
        elif start.value < find_val:
            return self.preorder_search(start.left, find_val)
        elif start.value > find_val:
            return self.preorder_search(start.right, find_val)
        
        return False

    def preorder_print(self, start, traversal):
        """Helper method - use this to create a 
        recursive print solution."""
        #Base case: when there are neither 
        if start== None:
            pass
        else:
            traversal.append(start.value)
            self.preorder_print(start.left, traversal)
            self.preorder_print(start.right, traversal)

tree = BST(6)

# Insert elements
tree.insert(2)
tree.insert(1)
tree.insert(3)
tree.insert(4)
tree.insert(5)
#Key realization is that the root of the binary search tree doesnt necessarily have to have the largest value in the whole tree. 
#Really, a larger value can be added on the right side of any node. That's why inserting at the end will work. 
print(tree.print_tree())

# Check search
# Should be True
print(tree.search(4))
# Should be False
print(tree.search(6))
# Out:
# 6-2-1-3-4-5
# False
# True

# %%
#Everything I had done so far was a recursive depth-first search, meaning I visited all the child elements recursive from left bottom to right top. 
#But this hackerrank question asks for a breadth first search, which is based off looking at the same level first. 
import sys

class Node:
    def __init__(self,data):
        self.right=self.left=None
        self.data = data
class Solution:
    def insert(self,root,data):
        if root==None:
            return Node(data)
        else:
            if data<=root.data:
                cur=self.insert(root.left,data)
                root.left=cur
            else:
                cur=self.insert(root.right,data)
                root.right=cur
        return root

    def levelOrder(self,root):
        #Write your code here
        while 

T=int(input())
myTree=Solution()
root=None
for i in range(T):
    data=int(input())
    root=myTree.insert(root,data)
myTree.levelOrder(root)

# %%
#2/12 Practice of binary search tree
class Node(object):
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BST(object):
    def __init__(self, root):
        self.root = Node(root)

    def insertMain(self, new_val, node):
        #The key realization from yesterday is the fact that inserting a node can always happens at the leaf.
        #I have to check if node even exists first. 
        if node:
            if new_val < node.value:
                if node.left == None:
                    node.left = Node(new_val)
                else:
                    self.insertMain(new_val, node.left)
            else:
                if node.right == None:
                    node.right = Node(new_val)
                else:
                    self.insertMain(new_val, node.right)
            '''
            if node.left == None and node.right == None:
                #Time to insert
                if new_val < node.value:
                    node.left = Node(new_val)
                else:
                    node.right = Node(new_val)
            #Not like they both have to be none. First we check smaller or bigger and then we can make decision on whether we add or make another recursive call. 
            else:
                if new_val < node.value:
                    self.insertMain(new_val, node.left)
                else:
                     self.insertMain(new_val, node.right)
            '''
        else:
            #The root statement might be causing some trouble. 
            self.root = Node(new_val)
        
    def insert(self, new_val):
        self.insertMain(new_val, self.root)

    def search(self, find_val):
        return self.searchRecusive(find_val, self.root)

    #I am pretty sure I am meant to do this recursively, going from top to bottom, prioratizing left
    def searchRecusive(self, find_val, node):
        #Set up base case: when we reached the leaf node and we didn't find anything.
        if node.left == None and node.right == None:
            return False

        else:
            if find_val == node.value:
                return True
            elif find_val < node.value:
                #We have to again check whether the node actually exists or not before returning anything. 
                if node.left:
                    return self.searchRecusive(find_val, node.left)
            else:
                if node.right:
                    return self.searchRecusive(find_val, node.right)

    def print_tree(self):
        """Print out all tree nodes
        as they are visited in
        a pre-order traversal."""
        arr = []
        #Since arrays are mutable by passing through methods. 
        finalString =""
        self.preorder_print(self.root, arr)
        for item in arr:
            finalString += str(item) + "-"

        return finalString[:len(finalString)-1]




    def preorder_search(self, start, find_val):
        """Helper method - use this to create a 
        recursive search solution."""
        #Base case: start just has value None
        if start==None:
            return False
        elif start.value == find_val:
            return True
        elif start.value < find_val:
            return self.preorder_search(start.left, find_val)
        elif start.value > find_val:
            return self.preorder_search(start.right, find_val)
        
        return False

    def preorder_print(self, start, traversal):
        """Helper method - use this to create a 
        recursive print solution."""
        #Base case: when there are neither 
        if start== None:
            pass
        else:
            traversal.append(start.value)
            self.preorder_print(start.left, traversal)
            self.preorder_print(start.right, traversal)

        
    
# Set up tree
tree = BST(4)

# Insert elements
tree.insert(2)
#print(tree.print_tree())
tree.insert(1)
#print(tree.print_tree())
#Problem happening when I add a value smaller. Rather than adding it to end, the code tries to replace self.root. 
tree.insert(3)
#print(tree.print_tree())
tree.insert(5)
#print(tree.print_tree())

# Check search
# Should be True
print(tree.search(4))
# Should be False
print(tree.search(6))
# Out:
# True
# False
