# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None

    
        

class MyLinkedList:

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.root = None
        

    def get(self, index: int) -> int:
        """
        Get the value of the index-th node in the linked list. If the index is invalid, return -1.
        """
        current = self.root
        counter = 0
        #We have to prevent error message when index is invalid. 
        while counter < index:
            if current.next:
                current = current.next
                counter += 1
            else:
                #get failing another test case at 
                return -1

        return current.val
        

    def addAtHead(self, val: int) -> None:
        """
        Add a node of value val before the first element of the linked list. After the insertion, the new node will be the first node of the linked list.
        """
        newNode = Node(val)
        #First have to check whether a node is already present or not. 
        if self.root:
            newNode.next = self.root
            self.root = newNode
        
        else:
            self.root = newNode

    def addAtTail(self, val: int) -> None:
        """
        Append a node of value val to the last element of the linked list.
        """
        newNode = Node(val)
        if self.root:
            current = self.root
            while current.next:
                current = current.next
            current.next = newNode

        else:
            self.root = newNode
        

    def addAtIndex(self, index: int, val: int) -> None:
        """
        Add a node of value val before the index-th node in the linked list. If index equals to the length of linked list, the node will be appended to the end of linked list. If index is greater than the length, the node will not be inserted.
        """
        #I guess I can first find the length of the linked list. 
        if index == 0:
            temp = self.root
            self.root = Node(val)
            self.root.next = temp

        else:
            current = self.root
            length = 0
            prev = None
            while current:
                length += 1
                #Just so I can use prev when index==length
                prev = current
                current = current.next


            if index > length:
                pass

            elif index == length:
                prev.next = Node(val)

            else:
                counter = 0
                current = self.root
                prev = None
                while current:
                    if counter == index:
                        newNode = Node(val)
                        prev.next, newNode.next = newNode, prev.next
                        break
                    else:
                        counter += 1
                        prev = current
                        current = current.next
                    
        

    def deleteAtIndex(self, index: int) -> None:
        """
        Delete the index-th node in the linked list, if the index is valid.
        """
        #!I have to consider the case when I am deleting the root node. 
        #We first have to check whether the index is valid so we check the length as we did for add. 
        current = self.root
        length = 0
        #If there are no values or only the root in the list, just make self.root=None

        #*Deleting root node.
        if index == 0:
            self.root = self.root.next
        else:
            while current:
                length += 1
                #Just so I can use prev when index==length
                prev = current
                current = current.next

            #We cannot delete a Node at index==length
            if index >= length:
                pass

            else:
                counter = 0
                current = self.root
                prev = None
                while current:
                    if counter == index:
                        #Check if prev exists
                        if prev:
                            prev.next = current.next
                        else:
                            self.root = None
                        break
                    else:
                        counter += 1
                        prev = current
                        current = current.next

    def print_list(self):
        #Just so I can comment easier, make it a returning function. 
        finalList = []
        current = self.root
        while current:
            finalList.append(current.val)
            current = current.next

        return finalList


a = MyLinkedList()
print(a.print_list())
a.addAtHead(1)
print(a.print_list())
a.addAtTail(3)
print(a.print_list())
a.addAtIndex(1, 2)
print(a.print_list())
print(a.get(1))
print(a.print_list())
print(a.deleteAtIndex(1))
print(a.print_list())
#Have to fix whatever error .get is giving me. 
print(a.get(1))
print(a.print_list())

# Your MyLinkedList object will be instantiated and called as such:
# obj = MyLinkedList()
# param_1 = obj.get(index)
# obj.addAtHead(val)
# obj.addAtTail(val)
# obj.addAtIndex(index,val)
# obj.deleteAtIndex(index)

# %%
#Some of the most time efficient solutions on leetcode
#The fastest solutions simply used lists but I bet the whole point was to use Node objects. 
class Node():
    def __init__(self, val):
        self.val = val
        self.next = None
        #*The fastest solutions often made use of the prev, even though it is a singly linked list. 
        self.prev = None

class MyLinkedList():
    def __init__(self):
        #The fastest solutions made use of self.size and already initialized self.tail at the moment.
            self.size = 0
            self.head = Node(0)
            self.tail = Node(0)
            #Two nodes are initialized at the beginning. 
            self.head.next = self.tail
            self.tail.prev = self.head


    def get(self, index):
        #Stores the size variable so that I don't have to loop all the time. 
        if index <0 or index >=self.size:
            return -1
        #It surely is a waste of time just going through all the elements. Instead, I can divide them into half and approach from either end depending on whether the index is at the beginning half or the end half.
        if index < self.size - index:
            current = self.head
            for i in range(index+1):
                current = current.next
        else:
            current = self.tail
            #We are going back
            for i in range(self.size - index):
                #Reason I had the prev variable was so it is easier to go back.
                current = current.prev

        return current.val

    def addAtHead(self, val):
        predecessor, successor = self.head, self.head.next
        self.size+=1
        to_add = ListNode(val)
        toadd.next, to_add.prev = succ, pred
        predecessor.next = to_add
        successor.prev = to_add

# %%
#The cycle question
#1. Approach 1 is to use a set and check everytime. 
#2. Use the runner approach
'''
However, my code was relatively inefficient because I had to do a lot of comparisons even though the loop structure was the same. 
'''

def hasCycle(self, head):
    slow = head
    fast = head
    #*I think what is implied here is that if fast.next exists, slow.next must also exist because slow is supposed to be way behind fast. 
    while slow and fast and fast.next:
        if slow == fast:
            return True

    return False

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    #Pretty sure this was the one where mycodeschool explained 3 solutions for. 
    def getIntersectionNode(self, headA: ListNode, headB: ListNode) -> ListNode:
        #First try brute force
        headAPointer = headA
        headBPointer = headB
        
        while head1Pointer:
            headBPointer = headB
            while headBPointer:
                if headAPointer == headBPointer:
                    return headAPointer
                headBPointer = headBPointer.next
                
            headAPointer = headA
        return None

# %%
#Different solution for removing n-th node from the end of the list. 
#1. My initial approach was to add a Node at the beginning so that curr.next.next will never give me an error (corner edge cases). https://leetcode.com/submissions/detail/456462644/ 
#2. 2nd approach: use the dummy node just like I did in the first try except use two pointer in which the 2 pointers are always n nodes apart (meaning there are n nodes in between). When the first pointer node is None, the second pointer is pointing at the node before the one I want to delete. So simply change the next thing. 
#3. Similar to the second approach except that I don't use a dummy node this time. I use 2 pointers that are have n-1 nodes in between them and I always check whether fast.next exists. If it doesn't, the second pointer is pointing at the node before the one I want to delete. 
def remove(head, n):
    slow = head
    fast = head
    #The for-loop efficiently checks whether we are trying to delete the head node or not. Checks until n-1
    for _ in range(n):
        fast = fast.next

    if not fast:
        #If the first element is removed, just return the next one. 
        return head.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    
    def getLength(self, head):
        length = 0
        current = head
        while current:
            length+=1
            current = current.next
            
            
        return length
    def removeNthFromEnd(self, head: ListNode, n: int) -> ListNode:
        #I could try creating a new node at the beginning so no error for len 1. 
        '''
        headLen = self.getLength(head)
        curr = head
        
        #I initially thought of doing headLen but I want to reach the element before it. 
        for i in range(0, headLen-n-1):
            curr = curr.next
        if curr.next:    
            curr.next = curr.next.next
            return head
        else:
            return None
        '''
        '''
        node = ListNode(None)
        node.next = head
        curr = node
        headLen = self.getLength(head)
        
        for i in range(0, headLen-n):
            curr = curr.next
        
        curr.next = curr.next.next
        return node.next
        '''
        '''
        a = head
        b = head
        #Keeping an n+1 distance
        for i in range(n):
            b = b.next
        
        #Eliminate cases when deleting the first node
        if not b:
            return a.next
        
        while b.next != None:
            a = a.next
            b = b.next
        
        a.next = a.next.next
        return head
        '''
        
        #The final approach that combines the previous 3 approaches:
        node = ListNode(None)
        node.next = head
        fast = node
        slow = node
        #Keeping n distance. 
        for i in range(n+1):
            fast = fast.next
            
        #The interesting part is that I don't have to check for the if statement like the previous solution because b.next because a.next = a.next.next will never return an error since even if len of linked list is 1, because of the dummy node, a.next = head and a.next.next ==None
        while fast != None:
            fast = fast.next
            slow = slow.next
            
        slow.next = slow.next.next
        
        return node.next

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        '''
        prev = None
        curr = head
        while curr:
            temp1 = prev
            temp2 = curr
            temp3 = curr.next
            prev = temp2
            curr.next = temp1
            curr = temp3
            
            #prev, curr, curr.next = curr, curr.next, prev
            
        return prev
        '''
        
        #For the recursive method, I probably have to do
        #current.next.next = current
        
        #Base case: recursion must stop when head.next is None. Just return head. I guess head==None is just 
        if head == None or head.next == None:
            return head
        else:
            p = self.reverseList(head.next)
            head.next.next = head
            head.next = None
            #I am kind of confused with this return p part. 
            return p

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def removeElements(self, head: ListNode, val: int) -> ListNode:
        #I think I saw this problem somewhere. 
        #Possible edge cases
        #1. Removing the first element
        #2. Several elements I have to remove are lined up in a row. 
        '''
        curr = head
        prev = None
        
        while curr:
            #First check if value match
            if curr.val == val:
                #Counter edge case 1
                if prev:
                    curr = curr.next
                    prev.next = curr
                    #Don't move prev yet
                else:
                    curr = curr.next
                    head = curr
            else:
                prev = curr
                curr = curr.next
                
        return head
        '''
        '''
        #2. I think the second way to do this faster is by completely eliminating the case of head needing removal. 
        while head and head.val==val:
            head = head.next
        
        #Head cannot be val
        curr = head
        
        #This while loop addresses the edge case of there being mulitple in a row by not moving current when val match. Compared to my first example, prev corresponds to curr and curr corresponds to curr.next. Just that it saves some memory
        #In my previous code, I had to check whether prev exists but in this case I don't need to because initially curr (head) is guaranteed to be different from val. 
        while curr and curr.next:
            if curr.next.val == val:
                curr.next = curr.next.next
            else:
                curr = curr.next
                
        return head
        '''
        
        #Then there is the way where I can insert a dummy node before the head node.
        #Pretty much the same idea as last time since this will ensure that the first node (prev) will not have value equal to val. 
        dummy = ListNode(None)
        dummy.next = head
        tail = dummy
        current = head
        while tail and current:
            if current.val == val:
                current = current.next
                tail.next = current
            else:
                tail = tail.next
                current = current.next
                
        return dummy.next

# %%
a = 1
b=a
a = 3
print(b)

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def oddEvenList(self, head: ListNode) -> ListNode:
        #I think one approach is like the quicksort approach where everytime I have 2 pointers. 
        #Slow pointer is pointing at the last odd number. 
        #Fast pointer is the one checking whether the value is odd or not 
        #If odd, add it after the node slow pointer is pointing at. 
        #Unlike quicksort, I don't need to do it recursively. 
        #Possible edge cases:
        #1. No nodes in the list. 
        #2. Only one node in the list (odd or even). 
        #3. Only odd or even nodes. 
        
        #First I could explicitly specify pointers and later see whether I can just use "curr"
        #Data I need to change/store
        #1. The node fast is pointing to
        #2. The node slow is pointing to. 
        #3. The node before the fast node -> To address this issue, I will check current.next instead of current -> To make sure I check the head node, I will make a dummy node. 

        #We aren't going to check the dummy node so I can just leave as 0. 
        '''
        dummy = ListNode()
        dummy.next = head
        fast = dummy
        slow = dummy
        
        while fast.next
            #Checking if even. 
            if fast.next.val % 2 == 0:
                #Need to accomodate order for the case when the first node is even
                slow.next = fast.next
                fast.next = fast.next.next
        '''
                
        #Honestly, the easiest solution is to probably link all odd nodes first then iterate again to link all the even nodes. O(2n) complexity but whatever. 
        
        #In this scenario, we are checking whether curr.next is odd or even. 
        #We have to store head since we want to loop twice
        '''
        head_copy = head
        curr = head
        #I still have to counter the edge case when the beginning node is even. In this case just advance.
        while curr and curr.val % 2 == 0:
            curr = curr.next
        #The head I am going to return
        #new_head only received the single curr value and it is not updated from there on. 
        new_head = curr
        
        #If I add this condition, the last node won't be checked. -> Not true because last node is checked when curr is the second last node. 
        while curr and curr.next:
            if curr.next.val % 2 == 0:
                #curr remains, just curr.next changes
                curr.next = curr.next.next
            else:
                #Add to new_head
                new_head.next = curr.next
                #curr is just acting as a pointer, not the entire linked list. 
                curr = curr.next
                
        #Check even. 
        even = head
        while even and even.next:
            if even.next.val % 2 == 0:
                curr.next = even.next
                #Save into new_head
                new_head.next = curr.next
                #curr.next = even.next
                curr = curr.next #->even
            else:
                even.next = even.next.next
                
        return new_head
        '''
        
        #This time, I want to make it s that it filters based on the values. 
        #head -> always points at beginning
        #odd -> pointer at the first odd value
        #evenHead -> always points at the beginning
        #even -> pointer at the first even value. 
        #odd and even are just pointer at the end of the branches. They don't traverse the whole linked list. 
        #Need to think about whether to make copy of head or no. 
        #Or I can create dummy nodes for both of them and when combining, remove dummy node. 
        oddHead = ListNode()
        odd = oddHead
        evenHead = ListNode()
        even = evenHead
        #print(self.showList(oddHead))
        #print(self.showList(evenHead))
        
        curr = head
        while curr:
            #print("while")
            if curr.val % 2 == 1:
                #print("odd")
                #The problem with adding current is that it carries on everything that is attached to curr.
                #Therefore, I have to explicitly set .next to 0. 
                odd.next = ListNode(curr.val)
                #odd.next.next = None
                odd = odd.next
                #odd.next = None
            else:
                #print("even")
                #I am getting mutability issues
                even.next = ListNode(curr.val)
                #I want to just affect event.next.next
                #even.next.next = None
                even = even.next
                #even.next = None
            curr = curr.next
            #print(self.showList(evenHead))

            
        #print(self.showList(oddHead))
        #print(self.showList(evenHead))
            
        odd.next = evenHead.next
        return oddHead.next
    
    def showList(self, head):
        curr = head
        l = []
        while curr:
            l.append(curr.val)
            curr = curr.next
        return l

# %%
#Leetcode question 403
#My initial approach was recursion but the compiler somehow didn't run properly. 

#1. Use a stack
        
    #I will do the iterative approach first then approach the recursive solution. 
    #1. 1st approach: append to stack. 
    def flatten(self, head):
        stack = []
        temp = head
        while head:
            if head.child:
                if head.next:
                    stack.append(head.next)
                head.next = head.child
                head.next.prev = head
                head.child = None
            elif head.next == None and stack:
                #We reached end. 
                head.next = stack.pop()
                head.next.prev = head
            head = head.next
            
        return temp

# %%
a = [1, 2]
#pop does both the removing and retrieving of the value, which is helpful. 
b = a.pop()
print(a, b)
print([1,2]+[3, 4])

# %%
#Since the exchanging part is a little difficult with linked list, I made a little sample. 
l = [1, 2, 3, 4, 5]
i = 4
for j in range(i):
    a = l[-1]
    l = l[:len(l)-1]
    l = [a] + l
    print(l)
    
print(l)

# %%
1%2
# Out:
# 1

# %%
word1 = "ab"
word2 = ""
sub1 = []
sub2 = []
for i in range(len(word1)):
    for j in range(len(word1)+1):
        sub1.append(word1[i:j])
        
for a in range(len(word2)):
    for j in range(len(word2)+1):
        sub1.append(word1[a:b])
        
print(sub1)
print(sub2)
# Out:
# ['', 'a', 'ab', '', '', 'b']
# []

# %%
word1 = "cacb"
word2 = "cbba"

sub1 = []
sub2 = []
for i in range(len(word1)):
    for j in range(len(word1)+1):
        sub1.append(word1[i:j])

for a in range(len(word2)):
    for b in range(len(word2)+1):
        sub1.append(word1[a:b])
        
pList = []
for a in range(len(sub1)):
    full = sub1[a][::-1]
    part = sub1[a][:-1][::-1]
    for b in range(len(sub2)):
        if full in sub2[b]:
            pList.append(sub1[a] + full)
        elif part in sub2[b]:
            pList.append(sub1[a] + part)
            
maxLen = 0
for item in pList:
    if len(item) > maxLen:
        maxLen = len(item)
        
print(maxLen)
# Out:
# 0

# %%
a =[]
b = a.pop()
b
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-cfa394b30a14> in <module>
#       1 a =[]
# ----> 2 b = a.pop()
#       3 b
#
# IndexError: pop from empty list
